# %%
# !cd drive/MyDrive/UAV/
# !ls

# %%
İ!pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="##")
project = rf.workspace("burhan-6fhqx").project("##")
dataset = project.version(1).download("yolov8")

# %%
# !git clone https://github.com/ultralytics/ultralytics.git

# %%
# !pip install wandb

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.0/716.0 kB 4.9 MB/s eta 0:00:00
# ...

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: burhan_clkkl. Use `wandb login --relogin` to force relogin

# %%
import wandb
api = wandb.Api()

run = api.run("user_name/project/<run_id>")
run.config["key"] = updated_value
run.update()

# %%
# !yolo train model=yolov8n.pt data=/content/drive/MyDrive/UAV/UAVDetection-1/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo train model=/content/drive/MyDrive/UAV/runs/detect/train2/weights/last.pt data=/content/drive/MyDrive/UAV/UAVDetection-1/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
